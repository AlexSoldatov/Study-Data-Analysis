# %%
import pandas

# %%
data = pandas.read_csv('titanic.csv', index_col='PassengerId')
data[:20]
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# ...

# %%
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
outFile1 = open('1_week_1_task.txt', 'w')
outFile2 = open('1_week_2_task.txt', 'w')
outFile3 = open('1_week_3_task.txt', 'w')
outFile4 = open('1_week_4_task.txt', 'w')
outFile5 = open('1_week_5_task.txt', 'w')
outFile6 = open('1_week_6_task.txt', 'w')

# %%
res = data['Sex'].value_counts()
print(res)
#print(res, file=outFile)
#outFile.close()

sex_counts = data['Sex'].value_counts()
print('{} {}'.format(sex_counts['male'], sex_counts['female']))
print('{} {}'.format(sex_counts['male'], sex_counts['female']), file=outFile1)
outFile1.close()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64
# 577 314

# %%
surv_counts = data['Survived'].value_counts()
surv_percent = 100.0 * surv_counts[1] / surv_counts.sum()
print( "{:0.2f}".format(surv_percent))
print( "{:0.2f}".format(surv_percent), file=outFile2)
outFile2.close()
# Out:
# 38.38

# %%
pclass_counts = data['Pclass'].value_counts()
 
pclass_percent = 100.0 * pclass_counts[1] / pclass_counts.sum()
print( "{:0.2f}".format(pclass_percent))
print( "{:0.2f}".format(pclass_percent), file=outFile3)
outFile3.close()
# Out:
# 24.24

# %%
ages = data['Age'].dropna() 
print("{:0.2f} {:0.2f}".format(ages.mean(), ages.median()))
print("{:0.2f} {:0.2f}".format(ages.mean(), ages.median()), file=outFile4)
outFile4.close()
# Out:
# 29.70 28.00

# %%
corr = data['SibSp'].corr(data['Parch'])
print("{:0.2f}".format(corr))
print("{:0.2f}".format(corr), file=outFile5)
outFile5.close()
# Out:
# 0.41

# %%
i = 0
res = data['Name'].get_values()
list_name = []
for name_row in res:
    is_woman = ("Miss." in name_row) or ("Mrs." in name_row)
    if is_woman:
        index_brace = name_row.find("(")
        if index_brace != -1:
            name_row = name_row[index_brace + 1:]
            index_space = name_row.find(" ")
            name_row = name_row[:index_space]
            list_name.append(name_row)
        else:
            index_point = name_row.find(".")
            name_row = name_row[index_point + 2:]
            index_space = name_row.find(" ")
            name_row = name_row[:index_space]
            list_name.append(name_row)
        # print(name_row)
        i += 1
        # print(res)
print(list_name)
dict_name = {}
dict_name["olo"] = 2
a = dict_name.get("olo")
for name in list_name:
    value = dict_name.get(name)
    if value is None:
        dict_name[name] = 1
    else:
        dict_name[name] = value + 1
sorted_x = sorted(dict_name.items(), key=operator.itemgetter(1))
print(sorted_x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-118-a1246b71a9f5> in <module>
#       1 i = 0
# ----> 2 res = data['Name'].get_values()
#       3 list_name = []
#       4 for name_row in res:
#       5     is_woman = ("Miss." in name_row) or ("Mrs." in name_row)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'get_values'
